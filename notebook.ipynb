# %%
import math 
loops = 2500000
a = range(1, loops)
def f(x):
    return 3 * math.log(x) + math.cos(x) ** 2
# %timeit r = [f(x) for x in a ]
# Out:
# 1.05 s ± 4.65 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
#Integer Values 
#Ex. 1
a = 10
result = type(a)
print('The data type of the following value: \n', result)
print('The value of a: \n', a)
a.bit_length()

#Ex. 2
b = 1 + 4
result = type(b)
print('The data type of the following value: \n', result )
print('The value of b: \n', b)

#Float Values
#Ex 1
c = 1/4
result = type(c)
print('the data type of the following value: \n', result )
print('The value of c is \n:', c)

#Ex 2
d = 1.6/4
result = type(d)
print('the data type of the following value: \n', result )
print('the value of d \n:', d)

#Ex 3
e = 0.35
result = type(e)
print('the data type of the following value: \n', result)
print('the value of e: \n', e)
# Out:
# The data type of the following value:
#  <class 'int'>
# The value of a:
#  10
# The data type of the following value:
#  <class 'int'>
# The value of b:
#  5
# the data type of the following value:
#  <class 'float'>
# The value of c is
# : 0.25
# the data type of the following value:
#  <class 'float'>
# the value of d
# : 0.4
# the data type of the following value:
#  <class 'float'>
# the value of e:
#  0.35
